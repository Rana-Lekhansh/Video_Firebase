# %%
# !pip install firebase-admin
# Out:
# ...
#   Obtaining dependency information for firebase-admin from https://files.pythonhosted.org/packages/04/5b/b70cbdbddd36d52e16218931a591783871fb5b307b9449ad8efff14eb0f4/firebase_admin-6.4.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for cachecontrol>=0.12.6 from https://files.pythonhosted.org/packages/a3/a9/7d331fec593a4b2953338df33e954aac6ff79eb5a073bca2783766bc7722/cachecontrol-0.14.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for google-api-python-client>=1.7.8 from https://files.pythonhosted.org/packages/9a/3d/1709ca24b093d37aa3233b78161a6d96d190922408041a6fea9df9c78646/google_api_python_client-2.120.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for google-cloud-storage>=1.37.1 from https://files.pythonhosted.org/packages/3d/48/574463fbf30c7021341ab0620e56103a8c49ad864bdd177935306c057986/google_cloud_storage-2.14.0-py2.py3-none-any.whl.metadata
# ...

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow("lekhansh", frame)
    if cv2.waitKey(1) & 0XFF == ord('q'):
        #cv2.imwrite("Lekhansh.jpg", frame)
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import firebase_admin
from firebase_admin import credentials, firestore

try:
    app = firebase_admin.get_app()
except ValueError:
    cred = credentials.Certificate("adminsdk.json")
    app = firebase_admin.initialize_app(cred, name='TestCam1')

db = firestore.client()

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    # Convert frame to bytes
    _, buffer = cv2.imencode('.jpg', frame)
    frame_bytes = buffer.tobytes()

    # Upload frame to Firestore
    doc_ref = db.collection('frames').document('frame')
    doc_ref.set({'image': frame_bytes})

    cv2.imshow("lekhansh", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
